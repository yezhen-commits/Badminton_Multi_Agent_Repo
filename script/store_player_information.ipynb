# %%
from dotenv import  load_dotenv

load_dotenv()
# Out:
# True

# %%
import os
import wikipedia
import psycopg2
from pgvector.psycopg2 import register_vector
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from dotenv import load_dotenv

load_dotenv()

def get_connection():
    conn = psycopg2.connect(os.getenv("DATABASE_URL"))
    return conn 

def create_tables():
    conn = get_connection()
    cursor = conn.cursor()
    
    cursor.execute("CREATE SCHEMA IF NOT EXISTS public")
    cursor.execute("SET search_path TO public")
    conn.commit()

    
    cursor.execute("CREATE EXTENSION IF NOT EXISTS vector")
    conn.commit()

    register_vector(conn)

    cursor.execute("CREATE SCHEMA IF NOT EXISTS badminton")

    cursor.execute("""
        CREATE TABLE IF NOT EXISTS badminton.singles_players (
            competitor_id   TEXT PRIMARY KEY,
            name            TEXT,
            country         TEXT,
            date_of_birth   TEXT,
            category        TEXT,
            rank            INTEGER,
            points          INTEGER
        )
    """)

    cursor.execute("""
        CREATE TABLE IF NOT EXISTS badminton.doubles_pairs (
            pair_id     TEXT PRIMARY KEY,
            pair_name   TEXT,
            category    TEXT,
            rank        INTEGER,
            points      INTEGER
        )
    """)

    cursor.execute("""
        CREATE TABLE IF NOT EXISTS badminton.doubles_players (
            id              SERIAL PRIMARY KEY,
            competitor_id   TEXT UNIQUE,
            name            TEXT,
            country         TEXT,
            date_of_birth   TEXT,
            pair_id         TEXT REFERENCES badminton.doubles_pairs(pair_id)
        )
    """)

    cursor.execute("""
        CREATE TABLE IF NOT EXISTS badminton.player_profiles (
            id              SERIAL PRIMARY KEY,
            competitor_id   TEXT,
            name            TEXT,
            content_type    TEXT,
            content         TEXT,
            chunk_index     INTEGER,
            embedding       vector(1536)
        )
    """)

    cursor.execute("""
        CREATE INDEX IF NOT EXISTS player_profiles_embedding_idx
        ON badminton.player_profiles
        USING ivfflat (embedding vector_cosine_ops)
        WITH (lists = 100)
    """)
    
    cursor.execute("""
        CREATE INDEX IF NOT EXISTS idx_profiles_name
        ON badminton.player_profiles (name);        
    """)
    
    cursor.execute("""
        CREATE INDEX IF NOT EXISTS idx_profiles_content_type 
        ON badminton.player_profiles (content_type);
    """)
    
    conn.commit()
    cursor.close()
    conn.close()
    print("Tables created successfully")

# %%
SINGLES_CATEGORIES = [
    "bwf_men_singles_world_ranking",
    "bwf_women_singles_world_ranking"
]

DOUBLES_CATEGORIES = [
    "bwf_men_doubles_world_ranking",
    "bwf_women_doubles_world_ranking",
    "bwf_mixed_doubles_world_ranking"
]

def insert_singles(data, category):
    conn = get_connection()
    cursor = conn.cursor()
    count = 0

    for ranking_block in data.get("rankings", []):
        if ranking_block.get("name") != category:
            continue

        for entry in ranking_block.get("competitor_rankings", []):
            if entry.get("rank", 999) > 100:
                continue

            comp = entry.get("competitor", {})

            cursor.execute("""
                INSERT INTO badminton.singles_players
                    (competitor_id, name, country, date_of_birth, category, rank, points)
                VALUES (%s, %s, %s, %s, %s, %s, %s)
                ON CONFLICT (competitor_id) DO UPDATE SET
                    rank     = EXCLUDED.rank,
                    points   = EXCLUDED.points,
                    category = EXCLUDED.category
            """, (
                comp.get("id"),
                comp.get("name"),
                comp.get("country"),
                comp.get("date_of_birth"),
                category,
                entry.get("rank"),
                entry.get("points")
            ))
            count += 1

    conn.commit()
    cursor.close()
    conn.close()
    print(f"Inserted {count} singles players for {category}")

# %%
def insert_doubles(data, category):
    conn = get_connection()
    cursor = conn.cursor()
    count = 0

    for ranking_block in data.get("rankings", []):
        if ranking_block.get("name") != category:
            continue

        for entry in ranking_block.get("competitor_rankings", []):
            if entry.get("rank", 999) > 100:
                continue

            comp = entry.get("competitor", {})
            players = comp.get("players", [])

            full_pair_name = " / ".join(p.get("name", "") for p in players) if players else comp.get("name")

            cursor.execute("""
                INSERT INTO badminton.doubles_pairs (pair_id, pair_name, category, rank, points)
                VALUES (%s, %s, %s, %s, %s)
                ON CONFLICT (pair_id) DO UPDATE SET
                    rank      = EXCLUDED.rank,
                    points    = EXCLUDED.points,
                    category  = EXCLUDED.category,
                    pair_name = EXCLUDED.pair_name
            """, (
                comp.get("id"),
                full_pair_name,
                category,
                entry.get("rank"),
                entry.get("points")
            ))

            for player in players:
                cursor.execute("""
                    INSERT INTO badminton.doubles_players
                        (competitor_id, name, country, date_of_birth, pair_id)
                    VALUES (%s, %s, %s, %s, %s)
                    ON CONFLICT (competitor_id) DO NOTHING
                """, (
                    player.get("id"),
                    player.get("name"),
                    player.get("country"),
                    player.get("date_of_birth"),
                    comp.get("id")
                ))
            count += 1

    conn.commit()
    cursor.close()
    conn.close()
    print(f"Inserted {count} doubles pairs for {category}")

# %%
SECTION_KEYWORDS = {
    "biography": [
        "early life", "personal life", "background",
        "education", "childhood", "family", "life"
    ],
    "career": [
        "career", "professional", "junior", "senior",
        "playing style", "technique", "training"
    ],
    "achievement": [
        "achievement", "title", "championship", "award",
        "honours", "honor", "medal", "record", "accomplishment",
        "grand prix", "superseries", "world tour"
    ]
}

def extract_wiki_sections(player_name: str) -> dict:
    """
    Extracts biography, career, and achievement sections from Wikipedia.
    Returns only sections that exist — safely handles missing sections.
    """
    sections_found = {
        "biography": "",
        "career": "",
        "achievement": ""
    }

    search_query = f"{player_name} badminton"

    def fetch_page(query: str):
        """Try fetching page, handle disambiguation by preferring badminton options."""
        try:
            return wikipedia.page(query, auto_suggest=True)
        except wikipedia.DisambiguationError as e:
            print(f"Disambiguation for '{query}', options: {e.options}")
            
            badminton_options = [opt for opt in e.options if "badminton" in opt.lower()]
            fallback = badminton_options[0] if badminton_options else e.options[0]
            print(f"Trying: {fallback}")
            return wikipedia.page(fallback)
        except wikipedia.PageError:
            print(f"No Wikipedia page for '{query}'")
            return None
        except Exception as e:
            print(f"Unexpected error fetching '{query}': {e}")
            return None

    page = fetch_page(search_query)

    if page is None:
        print(f"Could not find badminton page for '{player_name}', skipping.")
        return sections_found

    summary_lower = page.summary.lower()
    if "badminton" not in summary_lower:
        print(f"Warning: Page for '{player_name}' may not be about a badminton player.")
        print(f"Page title: {page.title}")

    if page.summary.strip():
        sections_found["biography"] = page.summary
        print(f"biography summary found")
    else:
        print(f"no biography summary found")

    try:
        content = page.content

        raw_sections = content.split("\n== ")

        for raw_section in raw_sections:
            if not raw_section.strip():
                continue

            lines = raw_section.strip().split("\n")
            section_title = lines[0].replace("==", "").strip().lower()
            section_body = "\n".join(lines[1:]).strip()

            if not section_body:
                continue

            for content_type, keywords in SECTION_KEYWORDS.items():
                if content_type == "biography":
                    continue  
                if any(keyword in section_title for keyword in keywords):
                    sections_found[content_type] += f"{section_title.title()}:\n{section_body}\n\n"
                    break

    except Exception as e:
        print(f"Error parsing sections for '{player_name}': {e}")

    for content_type, content in sections_found.items():
        if content.strip():
            print(f"{content_type:<15} content found")
        else:
            print(f"{content_type:<15} not found, skipping")

    return sections_found

# %%
def normalize_name(name: str) -> str:
    if "," in name:
        parts = name.split(",")
        return f"{parts[1].strip()} {parts[0].strip()}"
    return name.strip()

# %%
embeddings_model = OpenAIEmbeddings()

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    separators=["\n\n", "\n", ".", " "]
)

def store_player_profile(competitor_id: str, player_name: str):
    
    player_name = normalize_name(player_name)
    print(f"\n Adding {player_name} profile")

    sections = extract_wiki_sections(player_name)

    if not any(content.strip() for content in sections.values()):
        print(f"  No content found at all for {player_name}")
        return

    conn = get_connection()
    register_vector(conn) 
    cursor = conn.cursor()

    total_chunks = 0

    for content_type, content in sections.items():
        if not content.strip():
            continue

        chunks = text_splitter.split_text(content)

        for chunk_index, chunk in enumerate(chunks):
            if len(chunk.strip()) < 50:
                continue

            try:
                vector = embeddings_model.embed_query(chunk)

                cursor.execute("""
                    INSERT INTO badminton.player_profiles
                        (competitor_id, name, content_type, content, chunk_index, embedding)
                    VALUES (%s, %s, %s, %s, %s, %s)
                """, (
                    competitor_id,
                    player_name,
                    content_type,
                    chunk,
                    chunk_index,
                    vector
                ))
                total_chunks += 1

            except Exception as e:
                print(f" Failed embedding chunk {chunk_index} for {player_name}: {e}")
                continue

    conn.commit()
    cursor.close()
    conn.close()
    print(f" Stored {total_chunks} total chunks for {player_name}")

# %%
def fetch_all_profiles():
    conn = get_connection()
    cursor = conn.cursor()

    cursor.execute("SELECT competitor_id, name FROM badminton.singles_players WHERE name IS NOT NULL")
    singles = cursor.fetchall()

    cursor.execute("SELECT competitor_id, name FROM badminton.doubles_players WHERE name IS NOT NULL")
    doubles = cursor.fetchall()

    cursor.close()
    conn.close()

    seen = {}
    for competitor_id, name in singles + doubles:
        if competitor_id not in seen:
            seen[competitor_id] = name

    all_players = list(seen.items())
    print(f"\nFetching Wikipedia profiles for {len(all_players)} players...\n")

    success, skipped, failed = 0, 0, 0

    for competitor_id, name in all_players:
        try:
            store_player_profile(competitor_id, name)
            success += 1
        except Exception as e:
            print(f" Error processing {name}: {e}")
            failed += 1

    print(f"Done fetching player information, number of success is {success} and number of failed attempt is {failed}")

# %%
import requests

sportradar_api_key = os.getenv("SPORTRADAR_API_KEY")

def get_sportrader_info(url):
    
    headers = {
        "accept": "application/json",
        "x-api-key": sportradar_api_key
    }

    response = requests.get(url, headers=headers)

    if response.status_code != 200:
        return {"error": "Failed to fetch competition data"}
    
    data = response.json()
    return data

url = "https://api.sportradar.com/badminton/trial/v2/en/rankings.json"

data = get_sportrader_info(url)

# %%
create_tables()

for category in SINGLES_CATEGORIES:
    insert_singles(data, category)
# Out:
# Tables created successfully
# Inserted 98 singles players for bwf_men_singles_world_ranking
# Inserted 100 singles players for bwf_women_singles_world_ranking

# %%
for category in DOUBLES_CATEGORIES:
    insert_doubles(data, category)
# Out:
# Inserted 96 doubles pairs for bwf_men_doubles_world_ranking
# Inserted 87 doubles pairs for bwf_women_doubles_world_ranking
# Inserted 89 doubles pairs for bwf_mixed_doubles_world_ranking

# %%
fetch_all_profiles()

print("Database is filled")
# Out:
# Fetching Wikipedia profiles for 662 players...
#
#
#  Adding Kunlavut Vitidsarn profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 33 total chunks for Kunlavut Vitidsarn
#
#  Adding Yu Qi Shi profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 67 total chunks for Yu Qi Shi
#
#  Adding Anders Antonsen profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 26 total chunks for Anders Antonsen
#
#  Adding Jonatan Christie profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 41 total chunks for Jonatan Christie
#
#  Adding Christo Popov profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 15 total chunks for Christo Popov
#
#  Adding Tien Chen Chou profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 6 total chunks for Tien Chen Chou
#
#  Adding Shi Feng Li profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Shi Feng Li
#
#  Adding Chun-Yi Lin profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 13 total chunks for Chun-Yi Lin
#
#  Adding Alex Lanier profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 12 total chunks for Alex Lanier
#
#  Adding Kodai Naraoka profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 8 total chunks for Kodai Naraoka
#
#  Adding Kean Yew Loh profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 60 total chunks for Kean Yew Loh
#
#  Adding Lakshya Sen profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 26 total chunks for Lakshya Sen
#
#  Adding Victor Lai profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 7 total chunks for Victor Lai
#
#  Adding Alwi Farhan profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 15 total chunks for Alwi Farhan
#
#  Adding Kenta Nishimoto profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 9 total chunks for Kenta Nishimoto
#
#  Adding Toma Junior Popov profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 8 total chunks for Toma Junior Popov
#
#  Adding Hong Yang Weng profile
# No Wikipedia page for 'Hong Yang Weng badminton'
# Could not find badminton page for 'Hong Yang Weng', skipping.
#   No content found at all for Hong Yang Weng
#
#  Adding Guang Zu Lu profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 4 total chunks for Guang Zu Lu
#
#  Adding Yushi Tanaka profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 17 total chunks for Yushi Tanaka
#
#  Adding Yu Jen Chi profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Yu Jen Chi
#
#  Adding Koki Watanabe profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 14 total chunks for Koki Watanabe
#
#  Adding Cheuk Yiu Lee profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 5 total chunks for Cheuk Yiu Lee
#
#  Adding Jun Hao Leong profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 11 total chunks for Jun Hao Leong
#
#  Adding Rasmus Gemke profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Rasmus Gemke
#
#  Adding Ayush Shetty profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Ayush Shetty
#
#  Adding Zheng Xing Wang profile
# No Wikipedia page for 'Zheng Xing Wang badminton'
# Could not find badminton page for 'Zheng Xing Wang', skipping.
#   No content found at all for Zheng Xing Wang
#
#  Adding Panitchaphon Teeraratsakul profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Panitchaphon Teeraratsakul
#
#  Adding Ka Long Angus Ng profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 11 total chunks for Ka Long Angus Ng
#
#  Adding Nhat Nguyen profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Nhat Nguyen
#
#  Adding Srikanth Kidambi profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 25 total chunks for Srikanth Kidambi
#
#  Adding Brian Yang profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 9 total chunks for Brian Yang
#
#  Adding Jia Heng Jason Teh profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 16 total chunks for Jia Heng Jason Teh
#
#  Adding Chia Hao Lee profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 5 total chunks for Chia Hao Lee
#
#  Adding Tzu Wei Wang profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 5 total chunks for Tzu Wei Wang
#
#  Adding Haseena Sunil Prannoy profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 18 total chunks for Haseena Sunil Prannoy
#
#  Adding Arnaud Merkle profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 4 total chunks for Arnaud Merkle
#
#  Adding Yudai Okimoto profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 14 total chunks for Yudai Okimoto
#
#  Adding Hyeok Jin Jeon profile
# No Wikipedia page for 'Hyeok Jin Jeon badminton'
# Could not find badminton page for 'Hyeok Jin Jeon', skipping.
#   No content found at all for Hyeok Jin Jeon
#
#  Adding Magnus Johannesen profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Magnus Johannesen
#
#  Adding Justin Hoh profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 12 total chunks for Justin Hoh
#
#  Adding Moh. Zaki Ubaidillah profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 12 total chunks for Moh. Zaki Ubaidillah
#
#  Adding Jason Gunawan profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Jason Gunawan
#
#  Adding Prahdiska Bagas Shujiwo profile
# No Wikipedia page for 'Prahdiska Bagas Shujiwo badminton'
# Could not find badminton page for 'Prahdiska Bagas Shujiwo', skipping.
#   No content found at all for Prahdiska Bagas Shujiwo
#
#  Adding Tharun Mannepalli profile
# No Wikipedia page for 'Tharun Mannepalli badminton'
# Could not find badminton page for 'Tharun Mannepalli', skipping.
#   No content found at all for Tharun Mannepalli
#
#  Adding Kiran George profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 7 total chunks for Kiran George
#
#  Adding Po-Wei Wang profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Po-Wei Wang
#
#  Adding Anthony Sinisuka Ginting profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 48 total chunks for Anthony Sinisuka Ginting
#
#  Adding Li Yang Su profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 5 total chunks for Li Yang Su
#
#  Adding Joakim Oldorff profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 10 total chunks for Joakim Oldorff
#
#  Adding Aria Dinata profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 5 total chunks for Aria Dinata
#
#  Adding Sholeh Aidil profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 8 total chunks for Sholeh Aidil
#
#  Adding Kalle Koljonen profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Kalle Koljonen
#
#  Adding Minoru Koga profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 14 total chunks for Minoru Koga
#
#  Adding Julien Carraggi profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 5 total chunks for Julien Carraggi
#
#  Adding Kantaphon Wangcharoen profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 10 total chunks for Kantaphon Wangcharoen
#
#  Adding Zhe An Hu profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 10 total chunks for Zhe An Hu
#
#  Adding Mithun Manjunath profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Mithun Manjunath
#
#  Adding Jhuo-Fu Liao profile
# No Wikipedia page for 'Jhuo-Fu Liao badminton'
# Could not find badminton page for 'Jhuo-Fu Liao', skipping.
#   No content found at all for Jhuo-Fu Liao
#
#  Adding Harry Huang profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 3 total chunks for Harry Huang
#
#  Adding Ditlev Jaeger Holm profile
# No Wikipedia page for 'Ditlev Jaeger Holm badminton'
# Could not find badminton page for 'Ditlev Jaeger Holm', skipping.
#   No content found at all for Ditlev Jaeger Holm
#
#  Adding Hai Dang Nguyen profile
# Warning: Page for 'Hai Dang Nguyen' may not be about a badminton player.
# Page title: Nguyen
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     not found, skipping
#  Stored 1 total chunks for Hai Dang Nguyen
#
#  Adding Xuan Chen Zhu profile
# Warning: Page for 'Xuan Chen Zhu' may not be about a badminton player.
# Page title: Chen (surname)
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     not found, skipping
#  Stored 6 total chunks for Xuan Chen Zhu
#
#  Adding Chico Aura Dwi Wardoyo profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 17 total chunks for Chico Aura Dwi Wardoyo
#
#  Adding Priyanshu Rajawat profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Priyanshu Rajawat
#
#  Adding Tae Bin Yoo profile
# Warning: Page for 'Tae Bin Yoo' may not be about a badminton player.
# Page title: Yun Sung-bin
# biography summary found
# biography       content found
# career          content found
# achievement     not found, skipping
#  Stored 13 total chunks for Tae Bin Yoo
#
#  Adding Tian Yao Dong profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 11 total chunks for Tian Yao Dong
#
#  Adding Daniil Dubovenko profile
# No Wikipedia page for 'Daniil Dubovenko badminton'
# Could not find badminton page for 'Daniil Dubovenko', skipping.
#   No content found at all for Daniil Dubovenko
#
#  Adding Yen-Chen Ting profile
# Warning: Page for 'Yen-Chen Ting' may not be about a badminton player.
# Page title: Chen (surname)
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     not found, skipping
#  Stored 6 total chunks for Yen-Chen Ting
#
#  Adding Shogo Ogawa profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 9 total chunks for Shogo Ogawa
#
#  Adding Joshua Nguyen profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Joshua Nguyen
#
#  Adding Ping-Hsien Huang profile
# No Wikipedia page for 'Ping-Hsien Huang badminton'
# Could not find badminton page for 'Ping-Hsien Huang', skipping.
#   No content found at all for Ping-Hsien Huang
#
#  Adding Matthias Kicklitz profile
# No Wikipedia page for 'Matthias Kicklitz badminton'
# Could not find badminton page for 'Matthias Kicklitz', skipping.
#   No content found at all for Matthias Kicklitz
#
#  Adding Riki Takei profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 8 total chunks for Riki Takei
#
#  Adding Misha Zilberman profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 23 total chunks for Misha Zilberman
#
#  Adding Saneeth Dayanand Shimoga profile
# No Wikipedia page for 'Saneeth Dayanand Shimoga badminton'
# Could not find badminton page for 'Saneeth Dayanand Shimoga', skipping.
#   No content found at all for Saneeth Dayanand Shimoga
#
#  Adding Kevin Cordon profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 14 total chunks for Kevin Cordon
#
#  Adding Eogene EWE profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 7 total chunks for Eogene EWE
#
#  Adding Jonathan Matias profile
# No Wikipedia page for 'Jonathan Matias badminton'
# Could not find badminton page for 'Jonathan Matias', skipping.
#   No content found at all for Jonathan Matias
#
#  Adding Yu-Kai Wang profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Yu-Kai Wang
#
#  Adding S.Sankar Muthusamy Subramanian profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for S.Sankar Muthusamy Subramanian
#
#  Adding Zii Jia Lee profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 48 total chunks for Zii Jia Lee
#
#  Adding Bismo Raya Oktora profile
# No Wikipedia page for 'Bismo Raya Oktora badminton'
# Could not find badminton page for 'Bismo Raya Oktora', skipping.
#   No content found at all for Bismo Raya Oktora
#
#  Adding June Wei Cheam profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 13 total chunks for June Wei Cheam
#
#  Adding Mark Shelley Alcala profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 5 total chunks for Mark Shelley Alcala
#
#  Adding Ji Hoon Choi profile
# Warning: Page for 'Ji Hoon Choi' may not be about a badminton player.
# Page title: Kim Kang-hoon
# biography summary found
# biography       content found
# career          content found
# achievement     not found, skipping
#  Stored 5 total chunks for Ji Hoon Choi
#
#  Adding Dmitriy Panarin profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 5 total chunks for Dmitriy Panarin
#
#  Adding Rithvik Sanjeevi Satish Kumar profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Rithvik Sanjeevi Satish Kumar
#
#  Adding Christian Adinata profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 8 total chunks for Christian Adinata
#
#  Adding Sang Yong Park profile
# No Wikipedia page for 'Sang Yong Park badminton'
# Could not find badminton page for 'Sang Yong Park', skipping.
#   No content found at all for Sang Yong Park
#
#  Adding Viktor Axelsen profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 73 total chunks for Viktor Axelsen
#
#  Adding Jing Hong Kok profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 8 total chunks for Jing Hong Kok
#
#  Adding Viren Nettasinghe profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Viren Nettasinghe
#
#  Adding Enogat Roy profile
# Warning: Page for 'Enogat Roy' may not be about a badminton player.
# Page title: France at the 2025 Summer World University Games
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Enogat Roy
#
#  Adding Geonyeop Cho profile
# No Wikipedia page for 'Geonyeop Cho badminton'
# Could not find badminton page for 'Geonyeop Cho', skipping.
#   No content found at all for Geonyeop Cho
#
#  Adding Alap Mishra profile
# No Wikipedia page for 'Alap Mishra badminton'
# Could not find badminton page for 'Alap Mishra', skipping.
#   No content found at all for Alap Mishra
#
#  Adding Manraj Singh profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 5 total chunks for Manraj Singh
#
#  Adding Yohanes Saut Marcellyno profile
# No Wikipedia page for 'Yohanes Saut Marcellyno badminton'
# Could not find badminton page for 'Yohanes Saut Marcellyno', skipping.
#   No content found at all for Yohanes Saut Marcellyno
#
#  Adding Garret Tan profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     not found, skipping
#  Stored 3 total chunks for Garret Tan
#
#  Adding Se Young An profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 28 total chunks for Se Young An
#
#  Adding Zhi Yi Wang profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 18 total chunks for Zhi Yi Wang
#
#  Adding Yu Fei Chen profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 40 total chunks for Yu Fei Chen
#
#  Adding Akane Yamaguchi profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 49 total chunks for Akane Yamaguchi
#
#  Adding Yue Han profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 6 total chunks for Yue Han
#
#  Adding Putri Kusuma Wardani profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 21 total chunks for Putri Kusuma Wardani
#
#  Adding Ratchanok Intanon profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 50 total chunks for Ratchanok Intanon
#
#  Adding Pornpawee Chochuwong profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 6 total chunks for Pornpawee Chochuwong
#
#  Adding Tomoka Miyazaki profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 16 total chunks for Tomoka Miyazaki
#
#  Adding Fang Jie Gao profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 7 total chunks for Fang Jie Gao
#
#  Adding Supanida Katethong profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 11 total chunks for Supanida Katethong
#
#  Adding Michelle Li profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 21 total chunks for Michelle Li
#
#  Adding Venkata Sindhu Pusarla profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 94 total chunks for Venkata Sindhu Pusarla
#
#  Adding Pin-Chian Chiu profile
# No Wikipedia page for 'Pin-Chian Chiu badminton'
# Could not find badminton page for 'Pin-Chian Chiu', skipping.
#   No content found at all for Pin-Chian Chiu
#
#  Adding Nozomi Okuhara profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 33 total chunks for Nozomi Okuhara
#
#  Adding Ga Eun Kim profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 4 total chunks for Ga Eun Kim
#
#  Adding Busanan Ongbamrungphan profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 5 total chunks for Busanan Ongbamrungphan
#
#  Adding Hsiang Ti Lin profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 10 total chunks for Hsiang Ti Lin
#
#  Adding Yu Jin Sim profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 6 total chunks for Yu Jin Sim
#
#  Adding Line Christophersen profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 6 total chunks for Line Christophersen
#
#  Adding Mia Blichfeldt profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 13 total chunks for Mia Blichfeldt
#
#  Adding Line Hoejmark Kjaersfeldt profile
# No Wikipedia page for 'Line Hoejmark Kjaersfeldt badminton'
# Could not find badminton page for 'Line Hoejmark Kjaersfeldt', skipping.
#   No content found at all for Line Hoejmark Kjaersfeldt
#
#  Adding Natsuki Nidaira profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 6 total chunks for Natsuki Nidaira
#
#  Adding Pitchamon Opatniputh profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 6 total chunks for Pitchamon Opatniputh
#
#  Adding Riko Gunji profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 10 total chunks for Riko Gunji
#
#  Adding Thuy Linh Nguyen profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 6 total chunks for Thuy Linh Nguyen
#
#  Adding Unnati Hooda profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 6 total chunks for Unnati Hooda
#
#  Adding Beiwen Zhang profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 13 total chunks for Beiwen Zhang
#
#  Adding Hina Akechi profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 14 total chunks for Hina Akechi
#
#  Adding Yu-Hsun Huang profile
# No Wikipedia page for 'Yu-Hsun Huang badminton'
# Could not find badminton page for 'Yu-Hsun Huang', skipping.
#   No content found at all for Yu-Hsun Huang
#
#  Adding Kirsty Gilmour profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 9 total chunks for Kirsty Gilmour
#
#  Adding Jia Min Yeo profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 41 total chunks for Jia Min Yeo
#
#  Adding Qian Xi Han profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Qian Xi Han
#
#  Adding Tanvi Sharma profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 4 total chunks for Tanvi Sharma
#
#  Adding Neslihan Arin profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 9 total chunks for Neslihan Arin
#
#  Adding Shuo Yun Sung profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Shuo Yun Sung
#
#  Adding Letshanaa Karupathevan profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 6 total chunks for Letshanaa Karupathevan
#
#  Adding Ling Ching Wong profile
# No Wikipedia page for 'Ling Ching Wong badminton'
# Could not find badminton page for 'Ling Ching Wong', skipping.
#   No content found at all for Ling Ching Wong
#
#  Adding Isharani Baruah profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Isharani Baruah
#
#  Adding Julie Dawall Jakobsen profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Julie Dawall Jakobsen
#
#  Adding Manami Suizu profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 8 total chunks for Manami Suizu
#
#  Adding Ciou-Tong Tung profile
# No Wikipedia page for 'Ciou-Tong Tung badminton'
# Could not find badminton page for 'Ciou-Tong Tung', skipping.
#   No content found at all for Ciou-Tong Tung
#
#  Adding Devika Sihag profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Devika Sihag
#
#  Adding Wen Chi Hsu profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Wen Chi Hsu
#
#  Adding Polina Buhrova profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 8 total chunks for Polina Buhrova
#
#  Adding Gregoria Mariska Tunjung profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 27 total chunks for Gregoria Mariska Tunjung
#
#  Adding Wen Yu Zhang profile
# No Wikipedia page for 'Wen Yu Zhang badminton'
# Could not find badminton page for 'Wen Yu Zhang', skipping.
#   No content found at all for Wen Yu Zhang
#
#  Adding Rakshitha Sree Santhosh Ramraj profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Rakshitha Sree Santhosh Ramraj
#
#  Adding Anupama Upadhyaya profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 3 total chunks for Anupama Upadhyaya
#
#  Adding Anmol Kharb profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 6 total chunks for Anmol Kharb
#
#  Adding Jin Wei Goh profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 23 total chunks for Jin Wei Goh
#
#  Adding Amalie Schulz profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 1 total chunks for Amalie Schulz
#
#  Adding Malvika Bansod profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 7 total chunks for Malvika Bansod
#
#  Adding Yvonne Li profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Yvonne Li
#
#  Adding Kaloyana Nalbantova profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 4 total chunks for Kaloyana Nalbantova
#
#  Adding Juliana Viana Vieira profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 8 total chunks for Juliana Viana Vieira
#
#  Adding Tanya Hemanth profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Tanya Hemanth
#
#  Adding Tasnim Mir profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 8 total chunks for Tasnim Mir
#
#  Adding Shriyanshi Valishetty profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Shriyanshi Valishetty
#
#  Adding Ching Ping Huang profile
# No Wikipedia page for 'Ching Ping Huang badminton'
# Could not find badminton page for 'Ching Ping Huang', skipping.
#   No content found at all for Ching Ping Huang
#
#  Adding Yu Po Pai profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Yu Po Pai
#
#  Adding Ishika Jaiswal profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Ishika Jaiswal
#
#  Adding Aakarshi Kashyap profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 12 total chunks for Aakarshi Kashyap
#
#  Adding Sin Yan Happy Lo profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 5 total chunks for Sin Yan Happy Lo
#
#  Adding Thalita Ramadhani Wiryawan profile
# No Wikipedia page for 'Thalita Ramadhani Wiryawan badminton'
# Could not find badminton page for 'Thalita Ramadhani Wiryawan', skipping.
#   No content found at all for Thalita Ramadhani Wiryawan
#
#  Adding Su Yu Chen profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Su Yu Chen
#
#  Adding Min Ji Kim profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 7 total chunks for Min Ji Kim
#
#  Adding Ga Eun Park profile
# No Wikipedia page for 'Ga Eun Park badminton'
# Could not find badminton page for 'Ga Eun Park', skipping.
#   No content found at all for Ga Eun Park
#
#  Adding Pornpicha Choeikeewong profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 6 total chunks for Pornpicha Choeikeewong
#
#  Adding Ni Kadek Dhinda Amartya Pratiwi profile
# No Wikipedia page for 'Ni Kadek Dhinda Amartya Pratiwi badminton'
# Could not find badminton page for 'Ni Kadek Dhinda Amartya Pratiwi', skipping.
#   No content found at all for Ni Kadek Dhinda Amartya Pratiwi
#
#  Adding Mutiara Ayu Puspitasari profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 3 total chunks for Mutiara Ayu Puspitasari
#
#  Adding Asuka Takahashi profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Asuka Takahashi
#
#  Adding Ozge Bayrak profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Ozge Bayrak
#
#  Adding Clara Azurmendi profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Clara Azurmendi
#
#  Adding Tidapron Kleebyeesun profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     not found, skipping
#  Stored 1 total chunks for Tidapron Kleebyeesun
#
#  Adding Ashmita Chaliha profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 6 total chunks for Ashmita Chaliha
#
#  Adding Rachel Chan profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Rachel Chan
#
#  Adding Ting Yu Liang profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Ting Yu Liang
#
#  Adding Stefani Stoeva profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 17 total chunks for Stefani Stoeva
#
#  Adding Ines Lucia Castillo Salazar profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 5 total chunks for Ines Lucia Castillo Salazar
#
#  Adding Tereza Svabikova profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 6 total chunks for Tereza Svabikova
#
#  Adding Yi-Ting Hung profile
# No Wikipedia page for 'Yi-Ting Hung badminton'
# Could not find badminton page for 'Yi-Ting Hung', skipping.
#   No content found at all for Yi-Ting Hung
#
#  Adding Selvaduray Kisona profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 7 total chunks for Selvaduray Kisona
#
#  Adding Vivien Sandorhazi profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Vivien Sandorhazi
#
#  Adding Yu Wei Peng profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 84 total chunks for Yu Wei Peng
#
#  Adding Mansi Singh profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 6 total chunks for Mansi Singh
#
#  Adding Ella Lin profile
# Warning: Page for 'Ella Lin' may not be about a badminton player.
# Page title: United States at the 2025 Summer World University Games
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Ella Lin
#
#  Adding Keisha Fatimah Azzahra profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 6 total chunks for Keisha Fatimah Azzahra
#
#  Adding Shreya Lele profile
# No Wikipedia page for 'Shreya Lele badminton'
# Could not find badminton page for 'Shreya Lele', skipping.
#   No content found at all for Shreya Lele
#
#  Adding Siti Zulaikha profile
# No Wikipedia page for 'Siti Zulaikha badminton'
# Could not find badminton page for 'Siti Zulaikha', skipping.
#   No content found at all for Siti Zulaikha
#
#  Adding Joo Eun Kim profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 8 total chunks for Joo Eun Kim
#
#  Adding Tonrug Saeheng profile
# No Wikipedia page for 'Tonrug Saeheng badminton'
# Could not find badminton page for 'Tonrug Saeheng', skipping.
#   No content found at all for Tonrug Saeheng
#
#  Adding So Yul Lee profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     not found, skipping
#  Stored 1 total chunks for So Yul Lee
#
#  Adding Komang Ayu Cahya Dewi profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 10 total chunks for Komang Ayu Cahya Dewi
#
#  Adding Yi En Hsieh profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Yi En Hsieh
#
#  Adding Chiara Marvella Handoyo profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Chiara Marvella Handoyo
#
#  Adding Wen Jing Xu profile
# Warning: Page for 'Wen Jing Xu' may not be about a badminton player.
# Page title: Wen (surname 文)
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     not found, skipping
#  Stored 2 total chunks for Wen Jing Xu
#
#  Adding Chloe Hoang profile
# No Wikipedia page for 'Chloe Hoang badminton'
# Could not find badminton page for 'Chloe Hoang', skipping.
#   No content found at all for Chloe Hoang
#
#  Adding Aalisha Naik profile
# No Wikipedia page for 'Aalisha Naik badminton'
# Could not find badminton page for 'Aalisha Naik', skipping.
#   No content found at all for Aalisha Naik
#
#  Adding Agnes Korosi profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     not found, skipping
#  Stored 3 total chunks for Agnes Korosi
#
#  Adding Won Ho Kim profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 10 total chunks for Won Ho Kim
#
#  Adding Seung Jae Seo profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 14 total chunks for Seung Jae Seo
#
#  Adding Aaron Chia profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 29 total chunks for Aaron Chia
#
#  Adding Wooi Yik Soh profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 32 total chunks for Wooi Yik Soh
#
#  Adding Wei Keng Liang profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 12 total chunks for Wei Keng Liang
#
#  Adding Chang Wang profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 10 total chunks for Chang Wang
#
#  Adding Satwiksairaj Rankireddy profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 20 total chunks for Satwiksairaj Rankireddy
#
#  Adding Chirag Shetty profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 16 total chunks for Chirag Shetty
#
#  Adding Fajar Alfian profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 24 total chunks for Fajar Alfian
#
#  Adding Muhammad Shohibul Fikri profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 16 total chunks for Muhammad Shohibul Fikri
#
#  Adding Wei Chong Man profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 13 total chunks for Wei Chong Man
#
#  Adding Kai Wun Tee profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 12 total chunks for Kai Wun Tee
#
#  Adding Sze Fei Goh profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 16 total chunks for Sze Fei Goh
#
#  Adding Nur Izzuddin profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 15 total chunks for Nur Izzuddin
#
#  Adding Takuro Hoki profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 5 total chunks for Takuro Hoki
#
#  Adding Yugo Kobayashi profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Yugo Kobayashi
#
#  Adding Sabar Karyaman Gutama profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 9 total chunks for Sabar Karyaman Gutama
#
#  Adding Moh Reza Pahlevi Isfahani profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 9 total chunks for Moh Reza Pahlevi Isfahani
#
#  Adding BO Yang Chen profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     not found, skipping
#  Stored 1 total chunks for BO Yang Chen
#
#  Adding Yi (Chn) Liu profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 7 total chunks for Yi (Chn) Liu
#
#  Adding Kim Astrup profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 19 total chunks for Kim Astrup
#
#  Adding Anders Skaarup Rasmussen profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 13 total chunks for Anders Skaarup Rasmussen
#
#  Adding Hsiang Chieh Chiu profile
# No Wikipedia page for 'Hsiang Chieh Chiu badminton'
# Could not find badminton page for 'Hsiang Chieh Chiu', skipping.
#   No content found at all for Hsiang Chieh Chiu
#
#  Adding Chi-Lin Wang profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 10 total chunks for Chi-Lin Wang
#
#  Adding Raymond Indra profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 12 total chunks for Raymond Indra
#
#  Adding Nikolaus Joaquin profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 17 total chunks for Nikolaus Joaquin
#
#  Adding Jhe-Huei Lee profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 8 total chunks for Jhe-Huei Lee
#
#  Adding Po-Hsuan Yang profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Po-Hsuan Yang
#
#  Adding Ben Lane profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 8 total chunks for Ben Lane
#
#  Adding Sean Vendy profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 8 total chunks for Sean Vendy
#
#  Adding Junaidi Arif profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 8 total chunks for Junaidi Arif
#
#  Adding Roy King Yap profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 10 total chunks for Roy King Yap
#
#  Adding Leo Rolly Carnando profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 22 total chunks for Leo Rolly Carnando
#
#  Adding Bagas Maulana profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 12 total chunks for Bagas Maulana
#
#  Adding Daniel Lundgaard profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 5 total chunks for Daniel Lundgaard
#
#  Adding Mads Vestergaard profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 11 total chunks for Mads Vestergaard
#
#  Adding Hiroki Midorikawa profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 13 total chunks for Hiroki Midorikawa
#
#  Adding Kyohei Yamashita profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 15 total chunks for Kyohei Yamashita
#
#  Adding Fang-Chih Lee profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Fang-Chih Lee
#
#  Adding Fang-Jen Lee profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Fang-Jen Lee
#
#  Adding Min Hyuk Kang profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 5 total chunks for Min Hyuk Kang
#
#  Adding Dong Ju Ki profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 5 total chunks for Dong Ju Ki
#
#  Adding Kuang Heng Liu profile
# No Wikipedia page for 'Kuang Heng Liu badminton'
# Could not find badminton page for 'Kuang Heng Liu', skipping.
#   No content found at all for Kuang Heng Liu
#
#  Adding Po Han Yang profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 4 total chunks for Po Han Yang
#
#  Adding Kittinupong Kedren profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Kittinupong Kedren
#
#  Adding Dechapol Puavaranukroh profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 8 total chunks for Dechapol Puavaranukroh
#
#  Adding Nur Mohd Azriyn Ayub Azriyn profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 5 total chunks for Nur Mohd Azriyn Ayub Azriyn
#
#  Adding Wee Kiong Tan profile
# biography summary found
# ...
# achievement     content found
#  Stored 16 total chunks for Sapsiree Taerattanachai
#
#  Adding Marwan Faza profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Marwan Faza
#
#  Adding Aisyah Salsabila Putri Pranata profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 7 total chunks for Aisyah Salsabila Putri Pranata
#
#  Adding Pei Jing Lai profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 5 total chunks for Pei Jing Lai
#
#  Adding Jimmy Wong profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 6 total chunks for Jimmy Wong
#
#  Adding Su Yin Cheng profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     not found, skipping
#  Stored 1 total chunks for Su Yin Cheng
#
#  Adding Pang Ron Hoo profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Pang Ron Hoo
#
#  Adding Jia Xuan Gao profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     not found, skipping
#  Stored 2 total chunks for Jia Xuan Gao
#
#  Adding Meng Ying Wu profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Meng Ying Wu
#
#  Adding Jennie Gai profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 7 total chunks for Jennie Gai
#
#  Adding Thuc Phuong Nguyen profile
# No Wikipedia page for 'Thuc Phuong Nguyen badminton'
# Could not find badminton page for 'Thuc Phuong Nguyen', skipping.
#   No content found at all for Thuc Phuong Nguyen
#
#  Adding Marvin Emil Seidel profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 5 total chunks for Marvin Emil Seidel
#
#  Adding Lea Palermo profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 5 total chunks for Lea Palermo
#
#  Adding Dejan Ferdinansyah profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 17 total chunks for Dejan Ferdinansyah
#
#  Adding Bernadine Anindiya Wardana profile
# No Wikipedia page for 'Bernadine Anindiya Wardana badminton'
# Could not find badminton page for 'Bernadine Anindiya Wardana', skipping.
#   No content found at all for Bernadine Anindiya Wardana
#
#  Adding Chiew Sien Lim profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 4 total chunks for Chiew Sien Lim
#
#  Adding Tien Ci Wong profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 3 total chunks for Tien Ci Wong
#
#  Adding Chia Hsin Lee profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 5 total chunks for Chia Hsin Lee
#
#  Adding Ming Che Lu profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     not found, skipping
#  Stored 1 total chunks for Ming Che Lu
#
#  Adding Rehan Naufal Kusharjanto profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 12 total chunks for Rehan Naufal Kusharjanto
#
#  Adding Gloria Emanuelle Widjaja profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 35 total chunks for Gloria Emanuelle Widjaja
#
#  Adding Callum Hemming profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Callum Hemming
#
#  Adding Estelle van Leeuwen profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 1 total chunks for Estelle van Leeuwen
#
#  Adding Ruthvika Shivani Gadde profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 8 total chunks for Ruthvika Shivani Gadde
#
#  Adding Rohan Kapoor profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Rohan Kapoor
#
#  Adding Melati Daeva Oktavianti profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 29 total chunks for Melati Daeva Oktavianti
#
#  Adding Bobby Setiabudi profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 4 total chunks for Bobby Setiabudi
#
#  Adding Phuwanat Horbanluekit profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     not found, skipping
#  Stored 1 total chunks for Phuwanat Horbanluekit
#
#  Adding Yong Kai Terry Hee profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 21 total chunks for Yong Kai Terry Hee
#
#  Adding Yujia Jin profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 4 total chunks for Yujia Jin
#
#  Adding Arlya Nabila Thesa Munggaran profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Arlya Nabila Thesa Munggaran
#
#  Adding Bimo Prasetyo profile
# No Wikipedia page for 'Bimo Prasetyo badminton'
# Could not find badminton page for 'Bimo Prasetyo', skipping.
#   No content found at all for Bimo Prasetyo
#
#  Adding Amrutha Pramuthesh profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Amrutha Pramuthesh
#
#  Adding Ashith Surya profile
# No Wikipedia page for 'Ashith Surya badminton'
# Could not find badminton page for 'Ashith Surya', skipping.
#   No content found at all for Ashith Surya
#
#  Adding Francesca Corbett profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 10 total chunks for Francesca Corbett
#
#  Adding Mihaijlo Tomic profile
# No Wikipedia page for 'Mihaijlo Tomic badminton'
# Could not find badminton page for 'Mihaijlo Tomic', skipping.
#   No content found at all for Mihaijlo Tomic
#
#  Adding Andjela Vitman profile
# No Wikipedia page for 'Andjela Vitman badminton'
# Could not find badminton page for 'Andjela Vitman', skipping.
#   No content found at all for Andjela Vitman
#
#  Adding Francielton Farias profile
# No Wikipedia page for 'Francielton Farias badminton'
# Could not find badminton page for 'Francielton Farias', skipping.
#   No content found at all for Francielton Farias
#
#  Adding Ratchapol Makkasasithorn profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     not found, skipping
#  Stored 1 total chunks for Ratchapol Makkasasithorn
#
#  Adding Yu Jung Chae profile
# No Wikipedia page for 'Yu Jung Chae badminton'
# Could not find badminton page for 'Yu Jung Chae', skipping.
#   No content found at all for Yu Jung Chae
#
#  Adding Jongmin Lee profile
# No Wikipedia page for 'Jongmin Lee badminton'
# Could not find badminton page for 'Jongmin Lee', skipping.
#   No content found at all for Jongmin Lee
#
#  Adding Kristoffer Kolding profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Kristoffer Kolding
#
#  Adding Leona Michalski profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     not found, skipping
#  Stored 1 total chunks for Leona Michalski
#
#  Adding Pitha Haningtyas Mentari profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 12 total chunks for Pitha Haningtyas Mentari
#
#  Adding Rinov Rivaldy profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 16 total chunks for Rinov Rivaldy
#
#  Adding Filip Karlborg profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Filip Karlborg
#
#  Adding Tilda Sjoo profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 1 total chunks for Tilda Sjoo
#
#  Adding Supak Jomkoh profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Supak Jomkoh
#
#  Adding Sania Lima profile
# No Wikipedia page for 'Sania Lima badminton'
# Could not find badminton page for 'Sania Lima', skipping.
#   No content found at all for Sania Lima
#
#  Adding Oleksii Titov profile
# No Wikipedia page for 'Oleksii Titov badminton'
# Could not find badminton page for 'Oleksii Titov', skipping.
#   No content found at all for Oleksii Titov
#
#  Adding Timothy Lock profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Timothy Lock
#
#  Adding Xun Liew profile
# No Wikipedia page for 'Xun Liew badminton'
# Could not find badminton page for 'Xun Liew', skipping.
#   No content found at all for Xun Liew
#
#  Adding Yin Chak Chan profile
# No Wikipedia page for 'Yin Chak Chan badminton'
# Could not find badminton page for 'Yin Chak Chan', skipping.
#   No content found at all for Yin Chak Chan
#
#  Adding Tsz Yau Ng profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 5 total chunks for Tsz Yau Ng
#
#  Adding Debora Jille profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 4 total chunks for Debora Jille
#
#  Adding Brian Wassink profile
# No Wikipedia page for 'Brian Wassink badminton'
# Could not find badminton page for 'Brian Wassink', skipping.
#   No content found at all for Brian Wassink
#
#  Adding Yasemen Bektas profile
# biography summary found
# biography       content found
# career          content found
# achievement     not found, skipping
#  Stored 6 total chunks for Yasemen Bektas
#
#  Adding Emre Sonmez profile
# No Wikipedia page for 'Emre Sonmez badminton'
# Could not find badminton page for 'Emre Sonmez', skipping.
#   No content found at all for Emre Sonmez
#
#  Adding Koceila Mammeri profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 7 total chunks for Koceila Mammeri
#
#  Adding Tanina Violette Mammeri profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Tanina Violette Mammeri
#
#  Adding Sathish Kumar Karunakaran profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 3 total chunks for Sathish Kumar Karunakaran
#
#  Adding Aadya Variyath profile
# No Wikipedia page for 'Aadya Variyath badminton'
# Could not find badminton page for 'Aadya Variyath', skipping.
#   No content found at all for Aadya Variyath
#
#  Adding Edward Lau profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Edward Lau
#
#  Adding Shaunna Li profile
# No Wikipedia page for 'Shaunna Li badminton'
# Could not find badminton page for 'Shaunna Li', skipping.
#   No content found at all for Shaunna Li
#
#  Adding Franziska Volkmann profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Franziska Volkmann
#
#  Adding Patrick Volkmann profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Patrick Volkmann
#
#  Adding Iok Chong Leong profile
# No Wikipedia page for 'Iok Chong Leong badminton'
# Could not find badminton page for 'Iok Chong Leong', skipping.
#   No content found at all for Iok Chong Leong
#
#  Adding Weng Chi Ng profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Weng Chi Ng
#
#  Adding Lakshita Jaglan profile
# No Wikipedia page for 'Lakshita Jaglan badminton'
# Could not find badminton page for 'Lakshita Jaglan', skipping.
#   No content found at all for Lakshita Jaglan
#
#  Adding Mohit Jaglan profile
# No Wikipedia page for 'Mohit Jaglan badminton'
# Could not find badminton page for 'Mohit Jaglan', skipping.
#   No content found at all for Mohit Jaglan
#
#  Adding Akira Koga profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 16 total chunks for Akira Koga
#
#  Adding Janani Ananthakumar profile
# No Wikipedia page for 'Janani Ananthakumar badminton'
# Could not find badminton page for 'Janani Ananthakumar', skipping.
#   No content found at all for Janani Ananthakumar
#
#  Adding Yu Shan Lee profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Yu Shan Lee
#
#  Adding Ming Yap Too profile
# Warning: Page for 'Ming Yap Too' may not be about a badminton player.
# Page title: List of Chinese diaspora people
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     not found, skipping
#  Stored 0 total chunks for Ming Yap Too
#
#  Adding Wen Tse Chan profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 26 total chunks for Wen Tse Chan
#
#  Adding Yee Hern Wee profile
# No Wikipedia page for 'Yee Hern Wee badminton'
# Could not find badminton page for 'Yee Hern Wee', skipping.
#   No content found at all for Yee Hern Wee
#
#  Adding Nithin H.V. profile
# No Wikipedia page for 'Nithin H.V. badminton'
# Could not find badminton page for 'Nithin H.V.', skipping.
#   No content found at all for Nithin H.V.
#
#  Adding Srinidhi Narayanan profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 4 total chunks for Srinidhi Narayanan
#
#  Adding Diana Corleto Soto profile
# No Wikipedia page for 'Diana Corleto Soto badminton'
# Could not find badminton page for 'Diana Corleto Soto', skipping.
#   No content found at all for Diana Corleto Soto
#
#  Adding Christopher Alexander Martinez Salvador profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Christopher Alexander Martinez Salvador
#
#  Adding Eliana Zhang profile
# biography summary found
# biography       content found
# career          not found, skipping
# achievement     content found
#  Stored 2 total chunks for Eliana Zhang
#
#  Adding Josephine Wu profile
# biography summary found
# biography       content found
# career          content found
# achievement     content found
#  Stored 11 total chunks for Josephine Wu
# Done fetching player information, number of success is 661 and number of failed attempt is 1
# Database is filled
